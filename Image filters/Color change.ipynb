# %%
from PIL import Image

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pil = Image.open(r".\images\bob.jpg")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x226 at 0x119AE890580>

# %%
arr = np.array(pil)  # image to array of numpy type

# %%
arr
# Out:
# array([[[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [212,  60,  49],
#         [222,  70,  59],
#         [211,  60,  51]],
#
#        [[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [214,  62,  51],
#         [222,  69,  61],
#         [213,  62,  53]],
#
#        [[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [215,  63,  52],
#         [220,  67,  59],
#         [213,  62,  55]],
#
#        ...,
#
#        [[ 31,  38,  48],
#         [ 31,  41,  50],
#         [ 30,  43,  49],
#         ...,
#         [ 31,  22,  27],
#         [ 31,  22,  27],
#         [ 30,  21,  26]],
#
#        [[ 39,  48,  53],
#         [ 30,  39,  44],
#         [ 43,  52,  57],
#         ...,
#         [ 29,  25,  26],
#         [ 29,  25,  26],
#         [ 26,  24,  25]],
#
#        [[ 39,  48,  53],
#         [ 30,  39,  44],
#         [ 43,  52,  57],
# ...

# %%
arr.shape   #to get demension of matrix(M X N) and thickness or layers.
# Out:
# (226, 223, 3)

# %%
plt.imshow(arr) #display image

# %%
red = arr[:,:,0]

# %%
plt.imshow(red)

# %%
blue = arr[:,:,2]

# %%
plt.imshow(blue)

# %%
green = arr[:,:,1]

# %%
plt.imshow(green)

# %%
# COPY ARRAY TO OTHER

# %%
p2 = arr.copy()
p2
# Out:
# array([[[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [212,  60,  49],
#         [222,  70,  59],
#         [211,  60,  51]],
#
#        [[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [214,  62,  51],
#         [222,  69,  61],
#         [213,  62,  53]],
#
#        [[ 64, 180, 179],
#         [ 62, 181, 179],
#         [ 62, 181, 179],
#         ...,
#         [215,  63,  52],
#         [220,  67,  59],
#         [213,  62,  55]],
#
#        ...,
#
#        [[ 31,  38,  48],
#         [ 31,  41,  50],
#         [ 30,  43,  49],
#         ...,
#         [ 31,  22,  27],
#         [ 31,  22,  27],
#         [ 30,  21,  26]],
#
#        [[ 39,  48,  53],
#         [ 30,  39,  44],
#         [ 43,  52,  57],
#         ...,
#         [ 29,  25,  26],
#         [ 29,  25,  26],
#         [ 26,  24,  25]],
#
#        [[ 39,  48,  53],
#         [ 30,  39,  44],
#         [ 43,  52,  57],
# ...

# %%
plt.imshow(p2)

# %%
p2[:,:,[1,2]]
# Out:
# array([[[180, 179],
#         [181, 179],
#         [181, 179],
#         ...,
#         [ 60,  49],
#         [ 70,  59],
#         [ 60,  51]],
#
#        [[180, 179],
#         [181, 179],
#         [181, 179],
#         ...,
#         [ 62,  51],
#         [ 69,  61],
#         [ 62,  53]],
#
#        [[180, 179],
#         [181, 179],
#         [181, 179],
#         ...,
#         [ 63,  52],
#         [ 67,  59],
#         [ 62,  55]],
#
#        ...,
#
#        [[ 38,  48],
#         [ 41,  50],
#         [ 43,  49],
#         ...,
#         [ 22,  27],
#         [ 22,  27],
#         [ 21,  26]],
#
#        [[ 48,  53],
#         [ 39,  44],
#         [ 52,  57],
#         ...,
#         [ 25,  26],
#         [ 25,  26],
#         [ 24,  25]],
#
#        [[ 48,  53],
#         [ 39,  44],
#         [ 52,  57],
#         ...,
#         [ 25,  26],
#         [ 24,  25],
#         [ 24,  25]]], dtype=uint8)

# %%
p2[:,:,[1,2]]=0
p2
# Out:
# array([[[ 64,   0,   0],
#         [ 62,   0,   0],
#         [ 62,   0,   0],
#         ...,
#         [212,   0,   0],
#         [222,   0,   0],
#         [211,   0,   0]],
#
#        [[ 64,   0,   0],
#         [ 62,   0,   0],
#         [ 62,   0,   0],
#         ...,
#         [214,   0,   0],
#         [222,   0,   0],
#         [213,   0,   0]],
#
#        [[ 64,   0,   0],
#         [ 62,   0,   0],
#         [ 62,   0,   0],
#         ...,
#         [215,   0,   0],
#         [220,   0,   0],
#         [213,   0,   0]],
#
#        ...,
#
#        [[ 31,   0,   0],
#         [ 31,   0,   0],
#         [ 30,   0,   0],
#         ...,
#         [ 31,   0,   0],
#         [ 31,   0,   0],
#         [ 30,   0,   0]],
#
#        [[ 39,   0,   0],
#         [ 30,   0,   0],
#         [ 43,   0,   0],
#         ...,
#         [ 29,   0,   0],
#         [ 29,   0,   0],
#         [ 26,   0,   0]],
#
#        [[ 39,   0,   0],
#         [ 30,   0,   0],
#         [ 43,   0,   0],
# ...

# %%
plt.imshow(p2)
